# %%
# pandas numpy sklearn joblib livelossplot seaborn tqdm matplotlib keras_tqdm kiteconnect ipywidgets ta
import threading
import pandas as pd
import numpy as np
from sklearn.multioutput import MultiOutputRegressor
import joblib
import livelossplot
import seaborn as sns
from tqdm import tqdm
from matplotlib.pyplot import figure
from numpy import loadtxt
from stkdef60 import One_trian_stk_class
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from sklearn.metrics import plot_confusion_matrix
import numpy as np
import pandas as pd
import xgboost
import math
import csv as csv
from xgboost import plot_importance
from matplotlib import pyplot
from sklearn.model_selection import cross_val_score, KFold, train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt
from scipy.stats import skew
from collections import OrderedDict
from stkdef60 import One_trian_stk_class
import logging
import pickle
import matplotlib.pyplot as plt
from kiteconnect import KiteConnect
import ipywidgets as widgets
from ipywidgets import interact, interact_manual
from ta import add_all_ta_features
import ta
logging.basicConfig(level=logging.ERROR)
# from pactools.grid_search import GridSearchCVProgressBar
homediraddr = '/home/hemangjoshi37a_gmail_com'
kite = KiteConnect(api_key="w19o0chuo929jxkp")
kite.login_url()
# plt.style.use("seaborn")
kite = joblib.load('kitefile.p')
# Out:
# /home/hemangjoshi37a_gmail_com/.local/lib/python3.8/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
parameters_for_testing = {
    'estimator__colsample_bytree': [0.4, 0.8],
    'estimator__gamma': [0.03, 0.3],
    'estimator__min_child_weight': [1.5, 10],
    'estimator__learning_rate': [0.1, 0.07],
    'estimator__max_depth': [3, 15],
    'estimator__n_estimators': [10000],
    'estimator__reg_alpha': [1e-5, 0.75],
    'estimator__reg_lambda': [1e-5, 0.45],
    'estimator__subsample': [0.6, 0.95],
}

xgbmodel = xgboost.XGBRegressor(colsample_bytree=0.4,
                                gamma=0.5,
                                learning_rate=0.05,
                                max_depth=20,
                                min_child_weight=1.1,
                                n_estimators=10000,
                                reg_alpha=0.50,
                                gpu_id=0,
                                tree_method='gpu_hist',
                                reg_lambda=0.40,
                                subsample=0.6,
                                seed=50,
                                n_jobs=-1,
                                objective='reg:squarederror')

xx = {
    'name': 'TATASTEEL',
    'insttkn': 895745,
    'nbatch': 1,
    'nepochs': 5,
    'trainlen': 'all',
    'kite': kite
}
trainit = One_trian_stk_class(xx['name'], xx['insttkn'], xx['nbatch'],
                              xx['nepochs'], xx['trainlen'], xx['kite'])
trainit.load()
trainit.ta_xtrain_def()

reshapedxt = trainit.ta_x_train.reshape([
    trainit.ta_x_train.shape[0],
    trainit.ta_x_train.shape[1] * trainit.ta_x_train.shape[2]
])
xtreshaped = trainit.ta_x_test.reshape([
    trainit.ta_x_test.shape[0],
    trainit.ta_x_train.shape[1] * trainit.ta_x_train.shape[2]
])

multioutputregressor = MultiOutputRegressor(xgbmodel)

eval_set = [(reshapedxt, trainit.ta_y_train), (xtreshaped, trainit.ta_y_test)]

gsearch1 = GridSearchCV(estimator=multioutputregressor,
                        param_grid=parameters_for_testing,
                        n_jobs=8,
                        iid=False,
                        verbose=1,
                        scoring='neg_mean_squared_error')

gsearch1.fit(reshapedxt,
             trainit.ta_y_train,
             eval_metric=["error", "logloss"],
             eval_set=eval_set,
             verbose=False)
print(gsearch1.grid_scores_)
print('best params')
print(gsearch1.best_params_)
print('best score')
print(gsearch1.best_score_)
joblib.dump(gsearch1, "gsearch1.p")

# %%
joblib.dump(xtrain, "xtrain97.p")
joblib.dump(trainit.ta_y_train, "ytrain97.p")
joblib.dump(xtest, "xtest97.p")
joblib.dump(trainit.ta_y_test, "ytest97.p")

# %%
trainit.dxtrain.save_binary("dxtrain.p")
trainit.dytrain.save_binary("dytrain.p")
trainit.dxtest.save_binary("dxtest.p")
trainit.dytest.save_binary("dytest.p")

# %%
xtrain=joblib.load('xtrain.p')
ytrain=joblib.load('ytrain.p')
xtest=joblib.load('xtest.p')
ytest=joblib.load('ytest.p')
eval_set = [(xtrain, ytrain), (xtest,ytest)]

# %%
ytrain_o=ytrain
ytest_o=ytest

# %%
xx={'name':'TATASTEEL',
    'insttkn':895745,
    'nbatch':1,
    'nepochs':5,
    'trainlen':'all',
    'kite':kite}
trainit= One_trian_stk_class(xx['name'], xx['insttkn'],xx['nbatch'],xx['nepochs'],
                             xx['trainlen'],xx['kite'])
trainit.load()
trainit.ta_xtrain_def()

xtrain=trainit.ta_x_train.reshape([trainit.ta_x_train.shape[0],
                                   trainit.ta_x_train.shape[1]*trainit.ta_x_train.shape[2]])
xtest=trainit.ta_x_test.reshape([trainit.ta_x_test.shape[0],
                                  trainit.ta_x_train.shape[1]*trainit.ta_x_train.shape[2]])
eval_set = [(xtrain, trainit.ta_y_train), (xtest, trainit.ta_y_test)]

# %%
percent=0.60

xtrain=xtrain[-math.ceil((xtrain.shape[0])*percent):]
ytrain=ytrain[-math.ceil((ytrain.shape[0])*percent):]
eval_set = [(xtrain, ytrain), (xtest,ytest)]
print('xtrain = '+str(xtrain.shape))            
print('ytrain = '+str(ytrain.shape))

print('xtest = '+str(xtest.shape))      
print('ytest = '+str(ytest.shape))
# Out:
# xtrain = (291216, 4620)
# ytrain = (291216, 60)
# xtest = (4842, 4620)
# ytest = (4842, 60)

# %%
ytrain = ytrain[:, :1]
ytest = ytest[:, :1]
print(ytrain.shape)
print(ytest.shape)
# Out:
# (291216, 1)
# (4842, 1)

# %%
nr=xgboost.XGBRegressor(
                 colsample_bytree=0.6,
                 gamma=0.5,
                 learning_rate=0.07,
                 max_depth=25,
                 min_child_weight=1.2,
                 n_estimators=1000,
                 gpu_id=0,
                 tree_method='gpu_hist',
                 objective='reg:squarederror',
                 reg_alpha=0.75,
                 reg_lambda=0.45,
                 subsample=0.6,
                 seed=70,
                 verbosity=1,
                 predictor = 'gpu_predictor',
                 #n_jobs=-1,
)

eval_set=[(xtrain,ytrain),(xtest,ytest)]

nr.fit(xtrain,ytrain,
        eval_metric=["error", "logloss"],
            eval_set=eval_set,
            verbose=True
      )
joblib.dump(nr, "xgbregressor16.p")
# Out:
# [0]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [1]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [2]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [3]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [4]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [5]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [6]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [7]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [8]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [9]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [10]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [11]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [12]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [13]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [14]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [15]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [16]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [17]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [18]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [19]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [20]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [21]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [22]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [23]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [24]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [25]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [26]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [27]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [28]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [29]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [30]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [31]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [32]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [33]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [34]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [35]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [36]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [37]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [38]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [39]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
#
	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [954]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [955]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [956]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [957]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [958]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [959]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [960]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [961]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [962]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [963]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [964]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [965]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [966]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [967]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [968]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [969]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [970]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [971]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [972]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [973]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [974]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [975]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [976]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [977]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [978]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [979]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [980]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [981]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [982]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [983]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [984]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [985]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [986]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [987]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [988]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [989]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [990]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [991]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [992]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [993]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [994]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [995]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [996]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [997]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [998]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# [999]	validation_0-error:-522.90820	validation_0-logloss:-19264.65039	validation_1-error:-277.40436	validation_1-logloss:-10219.95410
# ['xgbregressor16.p']

# %%
multioutputregressor = MultiOutputRegressor(xgboost.XGBRegressor(
                colsample_bytree=0.4,
                 gamma=0.5,
                 learning_rate=0.1,
                 max_depth=10,
                 min_child_weight=1.3,
                 n_estimators=100,
                 gpu_id=0,
                 tree_method='gpu_hist',
                 objective='reg:squarederror',
                 reg_alpha=0.75,
                 reg_lambda=0.45,
                 subsample=0.6,
                 seed=15,
                 verbosity=1,
                 n_jobs=-1))

# multioutputregressor = MultiOutputRegressor(xgboost.XGBRegressor(objective='reg:squaredlogerror',
#                                                                  verbosity=1,
#                                                                  gpu_id=0,
#                                                                  n_jobs=-1
#                                                                  ),
#                                                                  n_jobs=-1
#                                                                  )

print(multioutputregressor.get_params())

# %%
res1=multioutputregressor.fit(xtrain,ytrain,
                          eval_metric=["error","logloss"], 
                          eval_set=eval_set,
                          verbose=True)

joblib.dump(multioutputregressor, "multioutputregressor11.p")

# %%
multioutputregressor.score(xtest, ytest)

# %%
corrMatrix = trainit.talibdf.corr()
figure(num=None, figsize=(8, 8), dpi=150)
sns.heatmap(corrMatrix)
plt.show()

# %%
pred0=nr.predict(xtest[0].reshape(1,-1))
act0=ytest[0][0]
diff=np.array(pred0[0])-np.array(act0)
print(diff)
# Out:
# 0.36994628906251137

# %%
pred1=nr.predict(xtest[1].reshape(1,-1))
act1=ytest[1]
diff1=np.array(pred1[0])-np.array(act1)
print(diff1)
# Out:
# [ 0.17260132  0.22260132  0.57260132  0.57260132  0.87260132  0.42260132
#  -0.07739868 -0.02739868 -0.07739868  0.27260132  0.27260132  0.17260132
#  -0.22739868 -0.12739868 -0.12739868 -0.27739868 -0.37739868 -0.32739868
#  -0.32739868 -0.07739868  0.17260132  0.12260132  0.07260132  0.02260132
#   0.02260132  0.02260132 -0.12739868  3.02260132  4.62260132  3.87260132
#   3.97260132  3.02260132  3.77260132  4.32260132  5.07260132  4.27260132
#   4.92260132  4.82260132  4.22260132  3.82260132  3.97260132  4.22260132
#   3.92260132  5.22260132  5.07260132  5.42260132  4.92260132  5.02260132
#   6.12260132  6.62260132  7.62260132  8.37260132  8.32260132  9.27260132
#   9.97260132  9.12260132  8.87260132  8.27260132  8.42260132  9.37260132]

# %%
pred2=nr.predict(xtest[2].reshape(1,-1))
act2=ytest[2]
diff2=np.array(pred2[0])-np.array(act2)
print(diff2)
# Out:
# [ 2.43933105e-01  5.93933105e-01  5.93933105e-01  8.93933105e-01
#   4.43933105e-01 -5.60668945e-02 -6.06689453e-03 -5.60668945e-02
#   2.93933105e-01  2.93933105e-01  1.93933105e-01 -2.06066895e-01
#  -1.06066895e-01 -1.06066895e-01 -2.56066895e-01 -3.56066895e-01
#  -3.06066895e-01 -3.06066895e-01 -5.60668945e-02  1.93933105e-01
#   1.43933105e-01  9.39331055e-02  4.39331055e-02  4.39331055e-02
#   4.39331055e-02 -1.06066895e-01  3.04393311e+00  4.64393311e+00
#   3.89393311e+00  3.99393311e+00  3.04393311e+00  3.79393311e+00
#   4.34393311e+00  5.09393311e+00  4.29393311e+00  4.94393311e+00
#   4.84393311e+00  4.24393311e+00  3.84393311e+00  3.99393311e+00
#   4.24393311e+00  3.94393311e+00  5.24393311e+00  5.09393311e+00
#   5.44393311e+00  4.94393311e+00  5.04393311e+00  6.14393311e+00
#   6.64393311e+00  7.64393311e+00  8.39393311e+00  8.34393311e+00
#   9.29393311e+00  9.99393311e+00  9.14393311e+00  8.89393311e+00
#   8.29393311e+00  8.44393311e+00  9.39393311e+00  9.44393311e+00]

# %%
pred0=multioutputregressor.predict(trainit.ta_x_test[0].reshape(1,60*trainit.ta_x_test.shape[2]))
act0=trainit.ta_y_test[0]
diff=np.array(pred0[0])-np.array(act0)
difflist=diff.tolist()
table0=pd.DataFrame({'true':act0,'pred':pred0[0]})
table0.plot(figsize=(13, 6))

# %%
pred1=multioutputregressor.predict(trainit.ta_x_test[21].reshape(1,60*trainit.ta_x_test.shape[2]))
act1=trainit.ta_y_test[21]
diff=np.array(pred1[0])-np.array(act1)
difflist1=diff.tolist()
table1=pd.DataFrame({'true':act1,'pred':pred1[0]})
table1.plot(figsize=(13, 6))

# %%
pred2=multioutputregressor.predict(trainit.ta_x_test[25].reshape(1,60*trainit.ta_x_test.shape[2]))
act2=trainit.ta_y_test[25]
diff=np.array(pred2[0])-np.array(act2)
difflist2=diff.tolist()
table2=pd.DataFrame({'true':act2,'pred':pred2[0]})
table2.plot(figsize=(13, 6))

# %%
# newdict={'table1_pred':table0['diff'].values.tolist(),'table2_pred':table1['diff'].values.tolist()} 
# hjdf=pd.DataFrame(newdict)
# hjdf.plot(figsize=(13, 6))

# %%
sample_no=0
table2=pd.DataFrame({'true':trainit.ta_y_test[sample_no],'pred':multioutputregressor.predict(trainit.ta_x_test[sample_no].reshape(1,60*trainit.ta_x_test.shape[2]))[0]})
table2.plot(figsize=(13, 6))

# %%
@interact
def shwo_gra(x=189):
    sample_no=x
#     sample_no=int(y)
    table2=pd.DataFrame({'true':trainit.ta_y_test[sample_no],'pred':multioutputregressor.predict(trainit.ta_x_test[sample_no].reshape(1,60*trainit.ta_x_test.shape[2]))[0]})
    print(table2.head())
    actar=np.array(trainit.ta_y_test[sample_no])
    predar=np.array(multioutputregressor.predict(trainit.ta_x_test[sample_no].reshape(1,60*trainit.ta_x_test.shape[2]))[0])
    diffdf=pd.DataFrame(actar-predar)
    diffdf.plot()
    diffa=(np.mean(np.abs(actar-predar)))
    print('acc : '+ str(diffa))
    return table2.plot(figsize=(10, 6))
#     return table2
#     return trainit.talibdf.loc[trainit.talibdf[column] = x]

# %%
import pandas as pd
from ta import add_all_ta_features
from ta.utils import dropna

df =trainit.df

df = add_all_ta_features(
    df, open="open", high="high", low="low", close="close", volume="volume")
